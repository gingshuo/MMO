# %%
from matplotlib import pyplot as plt
import numpy as np

# Generate 100 random data points along 3 dimensions
x, y, scale = np.random.randn(3, 100)
fig, ax = plt.subplots()

# Map each onto a scatterplot we'll create with Matplotlib
ax.scatter(x=x, y=y, c=scale, s=np.abs(scale)*500)
ax.set(title="Some random data, created with JupyterLab!")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取数据
data = {
    'rank': [1, 2, 3, 4, 5],
    'university': ['Harvard', 'MIT', 'Stanford', 'Cambridge', 'Oxford'],
    'overall_score': [100, 99, 98, 97, 96],
    'international_students_ratio': [0.2, 0.3, 0.25, 0.4, 0.35],
    'international_research_network': [80, 85, 70, 90, 75],
    'sustainability': [70, 60, 75, 80, 65],
    'employer_reputation': [95, 90, 85, 88, 92]
}

df = pd.DataFrame(data)
df = pd.read_csv('E:\关于教育\2 семинар\Методы машинного обучения в автоматизированных системах обработки ниформации и управления\ЛР\1\top 100 world university 2024 new.csv')

# 条形图显示前五名大学的排名
plt.figure(figsize=(10, 6))
plt.bar(df['university'], df['rank'], color='skyblue')
plt.xlabel('University')
plt.ylabel('Rank')
plt.title('Top 5 Universities by Rank')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# 散点图显示国际学生比例与国际研究网络的关系
plt.figure(figsize=(8, 6))
plt.scatter(df['international_students_ratio'], df['international_research_network'], color='orange', alpha=0.5)
plt.xlabel('International Students Ratio')
plt.ylabel('International Research Network')
plt.title('Relationship between International Students Ratio and International Research Network')
plt.grid(True)
plt.tight_layout()
plt.show()

# 折线图显示大学的可持续性得分
plt.figure(figsize=(10, 6))
plt.plot(df['university'], df['sustainability'], marker='o', linestyle='-', color='green')
plt.xlabel('University')
plt.ylabel('Sustainability Score')
plt.title('Sustainability Score of Universities')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.tight_layout()
plt.show()

# 箱线图显示大学的雇主声誉分数分布情况
plt.figure(figsize=(8, 6))
plt.boxplot(df['employer_reputation'], vert=False)
plt.xlabel('Employer Reputation')
plt.title('Distribution of Employer Reputation Score')
plt.grid(True)
plt.tight_layout()
plt.show()

# 饼图显示大学的国际学生比例分布
plt.figure(figsize=(8, 8))
labels = df['university']
sizes = df['international_students_ratio']
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Distribution of International Students Ratio among Universities')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 16
#       5 data = {
#       6     'rank': [1, 2, 3, 4, 5],
#       7     'university': ['Harvard', 'MIT', 'Stanford', 'Cambridge', 'Oxford'],
#    (...)
#      12     'employer_reputation': [95, 90, 85, 88, 92]
#      13 }
#      15 df = pd.DataFrame(data)
# ---> 16 df = pd.read_csv('E:\关于教育\2 семинар\Методы машинного обучения в автоматизированных системах обработки ниформации и управления\ЛР\1\top 100 world university 2024 new.csv')
#      18 # 条形图显示前五名大学的排名
#      19 plt.figure(figsize=(10, 6))
#
# File /lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
#didn't upload csvfile

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取数据
data = {
    'rank': [1, 2, 3, 4, 5],
    'university': ['Harvard', 'MIT', 'Stanford', 'Cambridge', 'Oxford'],
    'overall_score': [100, 99, 98, 97, 96],
    'international_students_ratio': [0.2, 0.3, 0.25, 0.4, 0.35],
    'international_research_network': [80, 85, 70, 90, 75],
    'sustainability': [70, 60, 75, 80, 65],
    'employer_reputation': [95, 90, 85, 88, 92]
}

df = pd.DataFrame(data)
df = pd.read_csv('top 100 world university 2024 new.csv')

# 条形图显示前五名大学的排名
plt.figure(figsize=(10, 6))
plt.bar(df['university'], df['rank'], color='skyblue')
plt.xlabel('University')
plt.ylabel('Rank')
plt.title('Top 5 Universities by Rank')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# 散点图显示国际学生比例与国际研究网络的关系
plt.figure(figsize=(8, 6))
plt.scatter(df['international_students_ratio'], df['international_research_network'], color='orange', alpha=0.5)
plt.xlabel('International Students Ratio')
plt.ylabel('International Research Network')
plt.title('Relationship between International Students Ratio and International Research Network')
plt.grid(True)
plt.tight_layout()
plt.show()

# 折线图显示大学的可持续性得分
plt.figure(figsize=(10, 6))
plt.plot(df['university'], df['sustainability'], marker='o', linestyle='-', color='green')
plt.xlabel('University')
plt.ylabel('Sustainability Score')
plt.title('Sustainability Score of Universities')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.tight_layout()
plt.show()

# 箱线图显示大学的雇主声誉分数分布情况
plt.figure(figsize=(8, 6))
plt.boxplot(df['employer_reputation'], vert=False)
plt.xlabel('Employer Reputation')
plt.title('Distribution of Employer Reputation Score')
plt.grid(True)
plt.tight_layout()
plt.show()

# 饼图显示大学的国际学生比例分布
plt.figure(figsize=(8, 8))
labels = df['university']
sizes = df['international_students_ratio']
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Distribution of International Students Ratio among Universities')
plt.tight_layout()
plt.show()
#the names are too many

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取数据
data = {
    'rank': [1, 2, 3, 4, 5],
    'university': ['Harvard', 'MIT', 'Stanford', 'Cambridge', 'Oxford'],
    'overall_score': [100, 99, 98, 97, 96],
    'international_students_ratio': [0.2, 0.3, 0.25, 0.4, 0.35],
    'international_research_network': [80, 85, 70, 90, 75],
    'sustainability': [70, 60, 75, 80, 65],
    'employer_reputation': [95, 90, 85, 88, 92]
}

df = pd.DataFrame(data)
df = pd.read_csv('top 100 world university 2024 new.csv')

# 设置图形大小
plt.figure(figsize=(12, 6))

# 条形图显示前五名大学的排名
plt.subplot(2, 3, 1)
plt.bar(df['university'], df['rank'], color='skyblue')
plt.xlabel('University')
plt.ylabel('Rank')
plt.title('Top 5 Universities by Rank')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# 散点图显示国际学生比例与国际研究网络的关系
plt.subplot(2, 3, 2)
plt.scatter(df['international_students_ratio'], df['international_research_network'], color='orange', alpha=0.5)
plt.xlabel('International Students Ratio')
plt.ylabel('International Research Network')
plt.title('Relationship between International Students Ratio and International Research Network')
plt.grid(True)
plt.tight_layout()

# 折线图显示大学的可持续性得分
plt.subplot(2, 3, 3)
plt.plot(df['university'], df['sustainability'], marker='o', linestyle='-', color='green')
plt.xlabel('University')
plt.ylabel('Sustainability Score')
plt.title('Sustainability Score of Universities')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.tight_layout()

# 箱线图显示大学的雇主声誉分数分布情况
plt.subplot(2, 3, 4)
plt.boxplot(df['employer_reputation'], vert=False)
plt.xlabel('Employer Reputation')
plt.title('Distribution of Employer Reputation Score')
plt.grid(True)
plt.tight_layout()

# 饼图显示大学的国际学生比例分布
plt.subplot(2, 3, 5)
labels = df['university']
sizes = df['international_students_ratio']
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Distribution of International Students Ratio among Universities')
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取数据
data = {
    'rank': [1, 2, 3, 4, 5],
    'university': ['Harvard', 'MIT', 'Stanford', 'Cambridge', 'Oxford'],
    'overall_score': [100, 99, 98, 97, 96],
    'international_students_ratio': [0.2, 0.3, 0.25, 0.4, 0.35],
    'international_research_network': [80, 85, 70, 90, 75],
    'sustainability': [70, 60, 75, 80, 65],
    'employer_reputation': [95, 90, 85, 88, 92]
}

df = pd.DataFrame(data)
df = pd.read_csv('top 100 world university 2024 new.csv')

# 设置图形大小
plt.figure(figsize=(12, 6))

# 条形图显示前五名大学的排名
plt.subplot(2, 3, 1)
plt.bar(df['rank'].astype(str), df['rank'], color='skyblue')  # 使用排名作为x轴，将排名转换为字符串类型
plt.xlabel('Rank')
plt.ylabel('Rank')
plt.title('Top 5 Universities by Rank')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# 散点图显示国际学生比例与国际研究网络的关系
plt.subplot(2, 3, 2)
plt.scatter(df['rank'], df['international_research_network'], color='orange', alpha=0.5)  # 使用排名作为x轴
plt.xlabel('Rank')
plt.ylabel('International Research Network')
plt.title('Relationship between Rank and International Research Network')
plt.grid(True)
plt.tight_layout()

# 折线图显示大学的可持续性得分
plt.subplot(2, 3, 3)
plt.plot(df['rank'].astype(str), df['sustainability'], marker='o', linestyle='-', color='green')  # 使用排名作为x轴，将排名转换为字符串类型
plt.xlabel('Rank')
plt.ylabel('Sustainability Score')
plt.title('Sustainability Score by Rank')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.tight_layout()

# 箱线图显示大学的雇主声誉分数分布情况
plt.subplot(2, 3, 4)
plt.boxplot(df['employer_reputation'], vert=False)
plt.xlabel('Employer Reputation')
plt.title('Distribution of Employer Reputation Score')
plt.grid(True)
plt.tight_layout()

# 饼图显示大学的国际学生比例分布
plt.subplot(2, 3, 5)
sizes = df['international_students_ratio']
plt.pie(sizes, labels=df['rank'].astype(str), autopct='%1.1f%%', startangle=140)  # 使用排名作为标签
plt.axis('equal')
plt.title('Distribution of International Students Ratio by Rank')
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取数据
data = {
    'rank': [1, 2, 3, 4, 5],
    'university': ['Harvard', 'MIT', 'Stanford', 'Cambridge', 'Oxford'],
    'overall_score': [100, 99, 98, 97, 96],
    'international_students_ratio': [0.2, 0.3, 0.25, 0.4, 0.35],
    'international_research_network': [80, 85, 70, 90, 75],
    'sustainability': [70, 60, 75, 80, 65],
    'employer_reputation': [95, 90, 85, 88, 92]
}

df = pd.DataFrame(data)
df = pd.read_csv('top 100 world university 2024 new.csv')

# 设置图形大小
plt.figure(figsize=(10, 6))

# 条形图显示前五名大学的排名
plt.subplot(2, 3, 1)
plt.bar(df['rank'].astype(str), df['rank'], color='skyblue')  # 使用排名作为x轴，将排名转换为字符串类型
plt.xlabel('Rank')
plt.ylabel('Rank')
plt.title('Top 5 Universities by Rank')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# 散点图显示国际学生比例与国际研究网络的关系
plt.subplot(2, 3, 2)
plt.scatter(df['rank'], df['international_research_network'], color='orange', alpha=0.5)  # 使用排名作为x轴
plt.xlabel('Rank')
plt.ylabel('International Research Network')
plt.title('Relationship between Rank and International Research Network')
plt.grid(True)
plt.tight_layout()

# 折线图显示大学的可持续性得分
plt.subplot(2, 3, 3)
plt.plot(df['rank'].astype(str), df['sustainability'], marker='o', linestyle='-', color='green')  # 使用排名作为x轴，将排名转换为字符串类型
plt.xlabel('Rank')
plt.ylabel('Sustainability Score')
plt.title('Sustainability Score by Rank')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.tight_layout()

# 箱线图显示大学的雇主声誉分数分布情况
plt.subplot(2, 3, 4)
plt.boxplot(df['employer_reputation'], vert=False)
plt.xlabel('Employer Reputation')
plt.title('Distribution of Employer Reputation Score')
plt.grid(True)
plt.tight_layout()

# 饼图显示大学的国际学生比例分布
plt.subplot(2, 3, 5)
sizes = df['international_students_ratio']
plt.pie(sizes, labels=df['rank'].astype(str), autopct='%1.1f%%', startangle=140)  # 使用排名作为标签
# Out:
# ([<matplotlib.patches.Wedge at 0x7122ab8>,
# ...
#  [Text(-0.8694619692715694, 0.6738218488520573, '1'),
#   Text(-0.9211342899112342, 0.6012583637253843, '2'),
#   Text(-0.969066397261958, 0.5204904587960564, '3'),
#   Text(-1.0042862719398002, 0.44878623418422453, '4'),
#   Text(-1.02623495001975, 0.39603260895784986, '5'),
#   Text(-1.0503047112638932, 0.32689449903121676, '6'),
#   Text(-1.0748273407347813, 0.23397903241316043, '7'),
#   Text(-1.0900024979344662, 0.14796808607474918, '8'),
#   Text(-1.0983460427981764, 0.06029900720232852, '9'),
#   Text(-1.0998351758299227, -0.019041691289463994, '10'),
#   Text(-1.096249621990489, -0.09075663218581083, '11'),
#   Text(-1.0875318733132386, -0.1651497033839238, '12'),
#   Text(-1.0758727628968872, -0.22912397966301692, '13'),
#   Text(-1.0565817585383919, -0.3059983456228473, '14'),
#   Text(-1.028922957779783, -0.38899556161183035, '15'),
#   Text(-0.999034025872523, -0.4603596584725244, '16'),
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取数据
data = {
    'rank': [1, 2, 3, 4, 5],
    'university': ['Harvard', 'MIT', 'Stanford', 'Cambridge', 'Oxford'],
    'overall_score': [100, 99, 98, 97, 96],
    'international_students_ratio': [0.2, 0.3, 0.25, 0.4, 0.35],
    'international_research_network': [80, 85, 70, 90, 75],
    'sustainability': [70, 60, 75, 80, 65],
    'employer_reputation': [95, 90, 85, 88, 92]
}

df = pd.DataFrame(data)
# df = pd.read_csv('top 100 world university 2024 new.csv')

# 设置图形大小
plt.figure(figsize=(10, 6))

# 条形图显示前五名大学的排名
plt.bar(df['rank'].astype(str), df['rank'], color='skyblue')  # 使用排名作为x轴，将排名转换为字符串类型
plt.xlabel('Rank')
plt.ylabel('Rank')
plt.title('Top 5 Universities by Rank')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# 散点图显示国际学生比例与国际研究网络的关系
plt.scatter(df['rank'], df['international_research_network'], color='orange', alpha=0.5)  # 使用排名作为x轴
plt.xlabel('Rank')
plt.ylabel('International Research Network')
plt.title('Relationship between Rank and International Research Network')
plt.grid(True)
plt.tight_layout()

# 折线图显示大学的可持续性得分
plt.plot(df['rank'].astype(str), df['sustainability'], marker='o', linestyle='-', color='green')  # 使用排名作为x轴，将排名转换为字符串类型
plt.xlabel('Rank')
plt.ylabel('Sustainability Score')
plt.title('Sustainability Score by Rank')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.tight_layout()

# 箱线图显示大学的雇主声誉分数分布情况
plt.boxplot(df['employer_reputation'], vert=False)
plt.xlabel('Employer Reputation')
plt.title('Distribution of Employer Reputation Score')
plt.grid(True)
plt.tight_layout()

# 饼图显示大学的国际学生比例分布
sizes = df['international_students_ratio']
plt.pie(sizes, labels=df['rank'].astype(str), autopct='%1.1f%%', startangle=140)  # 使用排名作为标签
# Out:
# ([<matplotlib.patches.Wedge at 0x694b048>,
# ...
#  [Text(-1.0573878721559553, 0.3032010682987468, '1'),
#   Text(-0.7912737398317816, -0.7641242494860546, '2'),
#   Text(0.37622223830690926, -1.033661853510779, '3'),
#   Text(1.0892948545934578, 0.15309056063721832, '4'),
#   Text(-0.1530906116307909, 1.08929484742677, '5')],
#  [Text(-0.5767570211759756, 0.16538240089022552, '13.3%'),
#   Text(-0.43160385809006263, -0.41679504517421156, '20.0%'),
#   Text(0.20521212998558686, -0.5638155564604249, '16.7%'),
#   Text(0.5941608297782497, 0.08350394216575545, '26.7%'),
#   Text(-0.08350396998043139, 0.5941608258691473, '23.3%')])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# 读取数据
# data = {
#     'rank': [1, 2, 3, 4, 5],
#     'university': ['Harvard', 'MIT', 'Stanford', 'Cambridge', 'Oxford'],
#     'overall_score': [100, 99, 98, 97, 96],
#     'international_students_ratio': [0.2, 0.3, 0.25, 0.4, 0.35],
#     'international_research_network': [80, 85, 70, 90, 75],
#     'sustainability': [70, 60, 75, 80, 65],
#     'employer_reputation': [95, 90, 85, 88, 92]
# }

# df = pd.DataFrame(data)
df = pd.read_csv('top 100 world university 2024 new.csv', encoding='ISO-8859-1')


# 散点图显示国际学生比例与国际研究网络的关系Scatter
plt.figure(figsize=(8, 6))
plt.scatter(df['international_students_ratio'], df['international_research_network'], color='orange', alpha=0.5)
plt.xlabel('International Students Ratio')
plt.ylabel('International Research Network')
plt.title('Relationship between International Students Ratio and International Research Network')
plt.grid(True)
plt.tight_layout()
plt.show()

# 折线图显示大学的可持续性得分Line
plt.figure(figsize=(10, 6))
plt.plot(df['rank'], df['sustainability'], marker='o', linestyle='-', color='green')
plt.xlabel('Rank')
plt.ylabel('Sustainability Score')
plt.title('Sustainability Score of Universities')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.tight_layout()
plt.show()

# 箱线图显示大学的雇主声誉分数分布情况Box
plt.figure(figsize=(8, 6))
plt.boxplot(df['employer_reputation'], vert=False)
plt.xlabel('Employer Reputation')
plt.title('Distribution of Employer Reputation Score')
plt.grid(True)
plt.tight_layout()
plt.show()

# 饼图显示大学的国际学生比例分布Pie
plt.figure(figsize=(8, 8))
labels = df['rank']
sizes = df['international_students_ratio']
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Distribution of International Students Ratio among Universities')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['rank'], df['overall_score'], color='skyblue')
plt.xlabel('Rank')
plt.ylabel('Overall Score')
plt.title('Overall Score of Universities')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
#bar

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['international_students_ratio'], df['international_research_network'], color='orange', alpha=0.5)
plt.xlabel('International Students Ratio')
plt.ylabel('International Research Network')
plt.title('Relationship between International Students Ratio and International Research Network')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['rank'], df['sustainability'], marker='o', linestyle='-', color='green')
plt.xlabel('Rank')
plt.ylabel('Sustainability Score')
plt.title('Sustainability Score of Universities')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['employer_reputation'], vert=False)
plt.xlabel('Employer Reputation')
plt.title('Distribution of Employer Reputation Score')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 8))
labels = df['rank']
sizes = df['international_students_ratio']
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Distribution of International Students Ratio among Universities')
plt.tight_layout()
plt.show()
